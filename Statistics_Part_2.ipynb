# %% [markdown]
# Answer 1
#
# Hypothesis testing is a statistical method used to make inferences or draw conclusions about a population based on sample data. It helps determine whether there is enough evidence to support a certain claim or assumption.

# %% [markdown]
# Answer 2
#
# The null hypothesis (denoted as
# 𝐻
# 0
# H
# 0
# ​
#  ) is the default assumption in a hypothesis test. It typically states that there is no effect, no difference, or no relationship between the phenomena being studied. In other words, it represents a position of "no change" or "status quo." For example, in a clinical trial, the null hypothesis might state that a new drug has no effect on patients compared to a placebo.
#
# In contrast, the alternative hypothesis (denoted as
# 𝐻
# 1
# H
# a
# ​or  is what you aim to support with your data. It proposes that there is an effect, a difference, or a relationship. Continuing with the clinical trial example, the alternative hypothesis would suggest that the new drug does have a significant effect on the patients compared to a placebo.

# %% [markdown]
# Answer 3
#
# The significance level (denoted as
# α) is the probability of rejecting the null hypothesis (
# 𝐻
# 0
#  ) when it is actually true. It represents the risk of a Type I error (false positive).

# %% [markdown]
# Answer 4
#
# The p-value is the probability of obtaining a result at least as extreme as the observed data, assuming the null hypothesis (
# 𝐻
# 0
#  ) is true.

# %% [markdown]
# Answer 5
#
# The p-value represents the probability of obtaining results as extreme as (or more extreme than) the observed data, assuming that the null hypothesis (
# 𝐻
# 0​
#  ) is true. It helps determine whether we should reject
# 𝐻
# 0

# %% [markdown]
# Answer 6
#
# n hypothesis testing, errors occur when we make incorrect conclusions about the null hypothesis (
# 𝐻
# 0 ). These errors are classified into two types:
#
# 🔹 Type I Error (False Positive)
# ✅ Definition: Rejecting
# 𝐻
# 0
#
#   when it is actually true.
# ✅ Mistakenly detecting an effect that doesn’t exist.
# ✅ The probability of a Type I error is
# α (significance level).
#
#
# 🔹 Type II Error (False Negative)
# ✅ Definition: Failing to reject
# 𝐻
# 0 when it is actually false.
# ✅ Missing a real effect.
# ✅ The probability of a Type II error is
# 𝛽
# β (related to statistical power).

# %% [markdown]
# Answer 7
#
# In hypothesis testing, we choose between a one-tailed test and a two-tailed test based on the direction of the hypothesis.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Answer 8
#
# A Z-test is a statistical test used to determine whether there is a significant difference between a sample mean and a population mean, or between two sample means, when the population standard deviation is known. It is based on the Z-score from the standard normal distribution.
#
# When is the Z-Test Used?
#
# ✅ Large Sample Size (
# n≥30)
# ✅ Population Standard Deviation (
# σ) is Known
# ✅ Data Follows a Normal Distribution (or sample size is large enough for the Central Limit Theorem (CLT) to apply)

# %% [markdown]
# Answer 9
#
# The Z-score (or standard score) measures how many standard deviations a data point is from the mean of a distribution. It is widely used in hypothesis testing, especially in Z-tests.
#
# What Does the Z-Score Represent?
#
# ✅ Indicates how far a value is from the mean in standard deviation units.
# ✅ Helps determine whether an observation is unusual in a normal distribution.
# ✅ Used in hypothesis testing to decide if we should reject the null hypothesis (
# 𝐻
# 0).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Answer 10
#
# The T-distribution (Student’s T-distribution) is a probability distribution used in hypothesis testing and confidence intervals when the sample size is small and the population standard deviation (σ) is unknown.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Answer 11
#
# Both Z-tests and T-tests are statistical methods used to compare means, but they differ in when and how they are applied.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Answer 12
#
# The T-test is a statistical method used to compare means and determine whether the difference between them is statistically significant. It is used when the sample size is small (n<30) and the population standard deviation (σ) is unknown.
#
#  When comparing sample means
# ✅ When sample size is small (n<30)
# ✅ When population standard deviation (σ) is unknown
# ✅ When data is approximately normally distributed

# %% [markdown]
# Answer 13
#
# Both Z-tests and T-tests are used to compare sample means in hypothesis testing. They follow the same general approach but differ in sample size and assumptions about the population standard deviation (σ).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Answer 14
#
# A confidence interval (CI) is a range of values used to estimate an unknown population parameter (e.g., mean, proportion) based on sample data. It provides a measure of uncertainty around the estimate.
#
#
# 🔹 How to Interpret a Confidence Interval?
#
# A 95% confidence interval means:
# 📌 "If we repeat this study multiple times, 95% of the calculated CIs will contain the true population mean."
#
# ✔ Example Interpretation:
#
# A 95% CI of (72, 78) for average test scores means we are 95% confident that the true population mean lies between 72 and 78.

# %% [markdown]
# Answer 15
#
# The Margin of Error (MOE) represents the amount of uncertainty or potential error in a statistical estimate. It tells us how far the sample statistic (e.g., sample mean) could be from the true population parameter due to sampling variability.
#
# A confidence interval (CI) is calculated as:
# CI=
# X
# ˉ
#  ±MOE
# Larger MOE → Wider CI → More uncertainty in the estimate
#
# Smaller MOE → Narrower CI → More precise estimate

# %% [markdown]
# Answer 16
#
# Bayes' Theorem is a fundamental concept in probability and statistics that describes how to update our beliefs about an event based on new evidence. It is widely used in fields like machine learning, medical diagnosis, and spam filtering.
#
# 🔹 Why is Bayes’ Theorem Important?
#
# ✔ It updates probabilities as new data becomes available.
# ✔ It helps in decision-making under uncertainty.
# ✔ It is used in Bayesian statistics, which is an alternative to frequentist statistics.
# ✔ It has practical applications in medical diagnosis, spam detection, machine learning, and more.

# %% [markdown]
# Answer 17
#
# The Chi-Square (χ 2 ) distribution is a continuous probability distribution that arises in statistics when dealing with variance and categorical data analysis. It is commonly used for hypothesis testing and confidence intervals for variance.
#
# 🔹 When is the Chi-Square Distribution Used?
# The Chi-Square test is mainly used for:
#
# 1️⃣ Chi-Square Goodness-of-Fit Test – Checks if a sample distribution matches an expected distribution.
# 2️⃣ Chi-Square Test for Independence – Tests if two categorical variables are related.
# 3️⃣ Variance Testing – Used to test if a population variance equals a specific value.

# %% [markdown]
# Answer 18
#
# The Chi-Square Goodness-of-Fit Test is a statistical test used to determine whether a sample distribution matches an expected (theoretical) distribution. It helps check if observed data follows a specified probability distribution.
#
# 🔹 How to Interpret Results?
# ✔ If
# <
# 0.05
# p<0.05 → Reject
# 0
# H  , meaning the die is likely biased.
# ✔ If
# >
# 0.05
# p>0.05 → Fail to reject
# 𝐻
# 0
#
#  , meaning we don’t have enough evidence to say it is biased.

# %% [markdown]
# Answer 19
#
# The F-distribution is a continuous probability distribution that arises in statistics, especially in the analysis of variance (ANOVA) and regression analysis. It is right-skewed and used to compare the variances of two populations.
#
#
# 🔹 When is the F-Distribution Used?
#
# The F-distribution is used in hypothesis testing when comparing two population variances. The most common applications include:
#
# 1️⃣ Analysis of Variance (ANOVA) – Tests if three or more population means are equal.
# 2️⃣ F-Test for Variance – Compares two sample variances to determine if they are significantly different.
# 3️⃣ Regression Analysis – Evaluates the overall significance of a regression model.

# %% [markdown]
# Answer 20
#
# Analysis of Variance (ANOVA) is a statistical test used to determine whether three or more population means are significantly different from each other. It helps answer the question:
#
# Are the differences in sample means due to real effects or just random chance?
#
# ANOVA compares the variance between groups to the variance within groups using the F-distribution.
#
# 🔹 Assumptions of ANOVA
#
# To ensure valid results, ANOVA relies on these assumptions:
#
# ✔ 1. Independence – Observations within and across groups must be independent.
# ✔ 2. Normality – The data within each group should follow a normal distribution.
# ✔ 3. Homogeneity of Variance – The variances of the groups should be roughly equal (checked using Levene’s Test).
#
# If assumptions are violated, non-parametric tests like the Kruskal-Wallis Test may be used.

# %% [markdown]
# Answer 21
#
# Analysis of Variance (ANOVA) is used to compare means across different groups. The type of ANOVA depends on the number of independent variables and whether the same subjects are measured multiple times.
#
# 🔹 1. One-Way ANOVA
# ✅ Purpose: Tests if three or more group means are significantly different for one independent variable.
# ✅ Example: Comparing student exam scores from three different schools.
#
# 🔹 2. Two-Way ANOVA
# ✅ Purpose: Tests how two independent variables affect a dependent variable.
# ✅ Example: Examining how teaching method (A, B, C) and study time (short, long) influence exam scores.

# %% [markdown]
# Answer 22
#
# The F-test is a statistical test used to compare the variances or overall significance of different groups. It is based on the F-distribution, which is a right-skewed distribution used in hypothesis testing.
#
# The F-test is widely used in ANOVA, regression analysis, and variance comparison.
#
# 🔹 When is the F-Test Used?
# The F-test is applied in several statistical analyses, including:
#
# 1️⃣ Comparing Variances (F-Test for Variance)
#
# Determines if two populations have equal variances.
#
# Example: Comparing variability in test scores between two schools.
#
# 2️⃣ ANOVA (Analysis of Variance)
#
# Used to test if three or more groups have different means.
#
# Example: Checking if different fertilizers affect plant growth.

# %% [markdown]
# ***Practical question***

# %%
#Answer 1

import numpy as np
import scipy.stats as stats

def z_test(sample_mean, pop_mean, pop_std, sample_size, alpha=0.05):
    # Compute the Z-score
    standard_error = pop_std / np.sqrt(sample_size)
    z_score = (sample_mean - pop_mean) / standard_error

    # Compute the p-value for two-tailed test
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Print results
    print(f"Z-Score: {z_score:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision
    if p_value < alpha:
        print("Reject H0: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to Reject H0: No significant difference between sample and population mean.")

# Given data
sample_mean = 52500  # Sample mean salary
pop_mean = 50000     # Population mean salary
pop_std = 8000       # Population standard deviation
sample_size = 30     # Sample size

# Perform Z-test
z_test(sample_mean, pop_mean, pop_std, sample_size)
# Out:
# Z-Score: 1.7116
# P-Value: 0.0870
# Fail to Reject H0: No significant difference between sample and population mean.

# %%
#Answer 2

import numpy as np
import scipy.stats as stats

# Simulate random data (sample of 30 production times from a normal distribution)
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=52, scale=5, size=30)  # Mean=52, Std=5, Sample size=30

# Population mean (hypothesized mean)
pop_mean = 50

# Perform a one-sample t-test
t_stat, p_value = stats.ttest_1samp(sample_data, pop_mean)

# Print results
print(f"Sample Mean: {np.mean(sample_data):.2f}")
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Decision at alpha = 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject H0: The sample mean is significantly different from 50 minutes.")
else:
    print("Fail to Reject H0: No significant difference from 50 minutes.")
# Out:
# Sample Mean: 51.06
# T-Statistic: 1.2893
# P-Value: 0.2075
# Fail to Reject H0: No significant difference from 50 minutes.

# %%
#Answer 3

import numpy as np
import scipy.stats as stats

def one_sample_z_test(sample_data, pop_mean, pop_std, alpha=0.05):
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    # Compute standard error
    standard_error = pop_std / np.sqrt(sample_size)

    # Compute Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Compute p-value for a two-tailed test
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Print results
    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-Score: {z_score:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision at alpha = 0.05
    if p_value < alpha:
        print("Reject H0: The sample mean is significantly different from 500g.")
    else:
        print("Fail to Reject H0: No significant difference from 500g.")

# Simulate sample data (30 product weights)
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=505, scale=20, size=30)  # Mean=505g, Std=20g, Sample=30

# Population parameters
pop_mean = 500  # Population mean weight
pop_std = 20    # Known population standard deviation

# Perform One-Sample Z-Test
one_sample_z_test(sample_data, pop_mean, pop_std)
# Out:
# Sample Mean: 501.24
# Z-Score: 0.3388
# P-Value: 0.7348
# Fail to Reject H0: No significant difference from 500g.

# %%
#Answer 4

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def two_tailed_z_test(sample_data, pop_mean, pop_std, alpha=0.05):
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    # Compute standard error
    standard_error = pop_std / np.sqrt(sample_size)

    # Compute Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Compute p-value for two-tailed test
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Print results
    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-Score: {z_score:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision at alpha = 0.05
    if p_value < alpha:
        print("Reject H0: The sample mean is significantly different from 20 hours.")
    else:
        print("Fail to Reject H0: No significant difference from 20 hours.")

    # Visualizing the Decision Region
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)

    critical_value = stats.norm.ppf(1 - alpha/2)  # Two-tailed critical value

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label="Standard Normal Distribution")
    plt.fill_between(x, y, where=(x < -critical_value) | (x > critical_value), color='red', alpha=0.5, label="Rejection Region")
    plt.axvline(z_score, color='blue', linestyle='dashed', label=f"Z-Score = {z_score:.2f}")
    plt.axvline(-critical_value, color='black', linestyle='dashed', label=f"Critical Value = ±{critical_value:.2f}")
    plt.axvline(critical_value, color='black', linestyle='dashed')
    plt.legend()
    plt.title("Two-Tailed Z-Test Decision Region")
    plt.xlabel("Z-Score")
    plt.ylabel("Probability Density")
    plt.show()

# Simulate sample data (30 battery life measurements)
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=21, scale=3, size=30)  # Mean=21 hours, Std=3, Sample=30

# Population parameters
pop_mean = 20  # Population mean battery life
pop_std = 3    # Known population standard deviation

# Perform Two-Tailed Z-Test with Visualization
two_tailed_z_test(sample_data, pop_mean, pop_std)
# Out:
# Sample Mean: 20.44
# Z-Score: 0.7952
# P-Value: 0.4265
# Fail to Reject H0: No significant difference from 20 hours.

# %%
#Answer 5

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def visualize_type1_type2(pop_mean=100, sample_mean=105, std_dev=15, sample_size=30, alpha=0.05):
    """
    Visualizes Type 1 and Type 2 errors in hypothesis testing.

    Parameters:
    - pop_mean: Population mean (H0)
    - sample_mean: Sample mean (HA)
    - std_dev: Population standard deviation
    - sample_size: Size of the sample
    - alpha: Significance level
    """
    # Compute standard error
    standard_error = std_dev / np.sqrt(sample_size)

    # Compute critical value for alpha
    critical_value = stats.norm.ppf(1 - alpha)  # One-tailed test

    # Compute beta (Type 2 error) for alternative hypothesis
    beta = stats.norm.cdf(critical_value, loc=sample_mean, scale=standard_error)

    # X-axis range for visualization
    x = np.linspace(pop_mean - 4 * std_dev, pop_mean + 4 * std_dev, 1000)

    # Normal distributions for H0 and HA
    y_h0 = stats.norm.pdf(x, pop_mean, standard_error)  # Null hypothesis
    y_ha = stats.norm.pdf(x, sample_mean, standard_error)  # Alternative hypothesis

    plt.figure(figsize=(10, 6))

    # Plot H0 distribution
    plt.plot(x, y_h0, label="H0: Null Distribution", color='blue')
    plt.fill_between(x, y_h0, where=(x > critical_value * standard_error + pop_mean), color='red', alpha=0.5, label="Type 1 Error (α)")

    # Plot HA distribution
    plt.plot(x, y_ha, label="HA: Alternative Distribution", color='green')
    plt.fill_between(x, y_ha, where=(x < critical_value * standard_error + pop_mean), color='purple', alpha=0.5, label="Type 2 Error (β)")

    # Vertical lines for critical value
    plt.axvline(x=critical_value * standard_error + pop_mean, color='black', linestyle='dashed', label=f"Critical Value = {critical_value * standard_error + pop_mean:.2f}")

    # Labels and legend
    plt.title("Type 1 and Type 2 Errors in Hypothesis Testing")
    plt.xlabel("Test Statistic")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.show()

    print(f"Critical Value (Zα): {critical_value:.2f}")
    print(f"Type 2 Error (β): {beta:.4f}")
    print(f"Power of the test (1 - β): {1 - beta:.4f}")

# Call function to visualize Type 1 & Type 2 errors
visualize_type1_type2()
# Out:
# Critical Value (Zα): 1.64
# Type 2 Error (β): 0.0000
# Power of the test (1 - β): 1.0000

# %%
#Answer 6

import numpy as np
import scipy.stats as stats

def independent_t_test(group1, group2, alpha=0.05):
    """
    Performs an independent T-test between two groups.

    Parameters:
    - group1: List or array of values for group 1
    - group2: List or array of values for group 2
    - alpha: Significance level (default = 0.05)
    """
    # Perform independent T-test (equal variance assumed)
    t_stat, p_value = stats.ttest_ind(group1, group2, equal_var=True)

    # Print results
    print(f"Group 1 Mean: {np.mean(group1):.2f}")
    print(f"Group 2 Mean: {np.mean(group2):.2f}")
    print(f"T-Statistic: {t_stat:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision based on alpha
    if p_value < alpha:
        print("Reject H0: There is a significant difference between the two groups.")
    else:
        print("Fail to Reject H0: No significant difference between the two groups.")

# Simulate test scores for two groups
np.random.seed(42)  # For reproducibility
group1 = np.random.normal(loc=75, scale=10, size=30)  # Mean=75, Std=10, Sample=30
group2 = np.random.normal(loc=80, scale=12, size=30)  # Mean=80, Std=12, Sample=30

# Perform Independent T-Test
independent_t_test(group1, group2)
# Out:
# Group 1 Mean: 73.12
# Group 2 Mean: 78.55
# T-Statistic: -2.0720
# P-Value: 0.0427
# Reject H0: There is a significant difference between the two groups.

# %%
#Answer 7

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def paired_t_test(before, after, alpha=0.05):
    """
    Performs a paired sample T-test and visualizes the results.

    Parameters:
    - before: Array of values before the intervention
    - after: Array of values after the intervention
    - alpha: Significance level (default = 0.05)
    """
    # Perform paired T-test
    t_stat, p_value = stats.ttest_rel(before, after)

    # Print results
    print(f"Before Training Mean: {np.mean(before):.2f}")
    print(f"After Training Mean: {np.mean(after):.2f}")
    print(f"T-Statistic: {t_stat:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision based on alpha
    if p_value < alpha:
        print("Reject H0: The training significantly improved productivity.")
    else:
        print("Fail to Reject H0: No significant improvement detected.")

    # Visualization
    plt.figure(figsize=(8, 5))
    plt.plot(before, label="Before Training", marker='o', linestyle='dashed', color='red')
    plt.plot(after, label="After Training", marker='o', linestyle='solid', color='green')
    plt.axhline(np.mean(before), color='red', linestyle='dotted', label=f"Mean Before: {np.mean(before):.2f}")
    plt.axhline(np.mean(after), color='green', linestyle='dotted', label=f"Mean After: {np.mean(after):.2f}")

    plt.title("Productivity Before vs. After Training")
    plt.xlabel("Employee Index")
    plt.ylabel("Productivity Score")
    plt.legend()
    plt.show()

# Simulate productivity scores before and after training
np.random.seed(42)  # For reproducibility
before_scores = np.random.normal(loc=70, scale=5, size=15)  # Mean=70, Std=5
after_scores = before_scores + np.random.normal(loc=5, scale=3, size=15)  # Improvement

# Perform Paired T-Test
paired_t_test(before_scores, after_scores)
# Out:
# Before Training Mean: 70.05
# After Training Mean: 73.89
# T-Statistic: -6.3731
# P-Value: 0.0000
# Reject H0: The training significantly improved productivity.

# %%
#Answer 8

import numpy as np
import scipy.stats as stats

def perform_z_t_tests(sample, pop_mean, pop_std, alpha=0.05):
    """
    Performs both a one-sample Z-test and a one-sample T-test on the same dataset.

    Parameters:
    - sample: Sample dataset (numpy array)
    - pop_mean: Known population mean
    - pop_std: Known population standard deviation (used for Z-test)
    - alpha: Significance level (default = 0.05)
    """

    # Sample statistics
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation (unbiased)

    # Compute standard errors
    standard_error_z = pop_std / np.sqrt(sample_size)  # For Z-test
    standard_error_t = sample_std / np.sqrt(sample_size)  # For T-test

    # Perform Z-test
    z_score = (sample_mean - pop_mean) / standard_error_z
    p_value_z = 2 * (1 - stats.norm.cdf(abs(z_score)))  # Two-tailed test

    # Perform T-test
    t_stat, p_value_t = stats.ttest_1samp(sample, pop_mean)

    # Print Results
    print(f"Sample Size: {sample_size}")
    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Population Mean: {pop_mean:.2f}")
    print(f"Population Std Dev: {pop_std:.2f}")

    print("\n--- Z-Test Results ---")
    print(f"Z-Score: {z_score:.4f}")
    print(f"P-Value (Z-test): {p_value_z:.4f}")
    if p_value_z < alpha:
        print("Reject H0: Significant difference found (Z-test).")
    else:
        print("Fail to Reject H0: No significant difference (Z-test).")

    print("\n--- T-Test Results ---")
    print(f"T-Statistic: {t_stat:.4f}")
    print(f"P-Value (T-test): {p_value_t:.4f}")
    if p_value_t < alpha:
        print("Reject H0: Significant difference found (T-test).")
    else:
        print("Fail to Reject H0: No significant difference (T-test).")

# Simulate a sample dataset (e.g., test scores)
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=75, scale=10, size=25)  # Sample size < 30 (small)

# Known population parameters
population_mean = 78
population_std = 10  # Known for Z-test

# Perform both Z-test and T-test
perform_z_t_tests(sample_data, population_mean, population_std)
# Out:
# Sample Size: 25
# Sample Mean: 73.36
# Population Mean: 78.00
# Population Std Dev: 10.00
#
# --- Z-Test Results ---
# Z-Score: -2.3175
# P-Value (Z-test): 0.0205
# Reject H0: Significant difference found (Z-test).
#
# --- T-Test Results ---
# T-Statistic: -2.4228
# P-Value (T-test): 0.0233
# Reject H0: Significant difference found (T-test).

# %%
#Answer 9

import numpy as np
import scipy.stats as stats

def confidence_interval(sample, confidence=0.95):
    """
    Calculates the confidence interval for a sample mean.

    Parameters:
    - sample: List or numpy array of sample data
    - confidence: Confidence level (default = 95%)

    Returns:
    - Tuple containing lower and upper bounds of the confidence interval
    """
    n = len(sample)  # Sample size
    mean = np.mean(sample)  # Sample mean
    std_dev = np.std(sample, ddof=1)  # Sample standard deviation (unbiased)

    # Get the critical t-value for the given confidence level
    t_critical = stats.t.ppf((1 + confidence) / 2, df=n-1)

    # Compute margin of error
    margin_of_error = t_critical * (std_dev / np.sqrt(n))

    # Confidence interval bounds
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    return lower_bound, upper_bound

# Simulate sample data (e.g., student test scores)
np.random.seed(42)
sample_data = np.random.normal(loc=75, scale=10, size=30)  # Mean=75, Std=10, Sample=30

# Compute confidence interval
ci_lower, ci_upper = confidence_interval(sample_data)

# Print results
print(f"Sample Mean: {np.mean(sample_data):.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 73.12
# 95% Confidence Interval: (69.76, 76.48)

# %%
#Answer 10

import numpy as np
import scipy.stats as stats

def margin_of_error(sample, confidence=0.95):
    """
    Calculates the margin of error for a given sample and confidence level.

    Parameters:
    - sample: List or numpy array of sample data
    - confidence: Confidence level (default = 95%)

    Returns:
    - Margin of Error (MoE)
    """
    n = len(sample)  # Sample size
    std_dev = np.std(sample, ddof=1)  # Sample standard deviation (unbiased)

    # Get the critical t-value for the given confidence level
    t_critical = stats.t.ppf((1 + confidence) / 2, df=n-1)

    # Compute margin of error
    moe = t_critical * (std_dev / np.sqrt(n))

    return moe

# Simulate sample data (e.g., survey responses)
np.random.seed(42)
sample_data = np.random.normal(loc=75, scale=10, size=30)  # Mean=75, Std=10, Sample=30

# Compute margin of error
moe_value = margin_of_error(sample_data)

# Print results
print(f"Sample Size: {len(sample_data)}")
print(f"Sample Standard Deviation: {np.std(sample_data, ddof=1):.2f}")
print(f"95% Margin of Error: ±{moe_value:.2f}")
# Out:
# Sample Size: 30
# Sample Standard Deviation: 9.00
# 95% Margin of Error: ±3.36

# %%
#Answer 11

def bayes_theorem(prior, likelihood, false_positive):
    """
    Computes the posterior probability using Bayes' Theorem.

    Parameters:
    - prior: P(H) - Prior probability of hypothesis (having the disease)
    - likelihood: P(E|H) - Probability of evidence given hypothesis (test accuracy)
    - false_positive: P(E|¬H) - Probability of false positive (test error rate)

    Returns:
    - Posterior probability P(H|E)
    """
    # Compute total probability of evidence P(E)
    evidence = (likelihood * prior) + (false_positive * (1 - prior))

    # Compute posterior probability using Bayes' theorem
    posterior = (likelihood * prior) / evidence

    return posterior

# Given values
prior_prob = 0.01  # 1% of people have the disease
likelihood_prob = 0.90  # 90% accuracy for those with the disease
false_positive_prob = 0.05  # 5% false positives for healthy people

# Calculate posterior probability
posterior_prob = bayes_theorem(prior_prob, likelihood_prob, false_positive_prob)

# Display result
print(f"Probability of having the disease given a positive test: {posterior_prob:.4f} ({posterior_prob*100:.2f}%)")
# Out:
# Probability of having the disease given a positive test: 0.1538 (15.38%)

# %%
#Answer 12

import numpy as np
import scipy.stats as stats
import pandas as pd

# Create observed frequency table (contingency table)
observed = np.array([[30, 10],  # Male: 30 prefer A, 10 prefer B
                      [15, 25]]) # Female: 15 prefer A, 25 prefer B

# Perform Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(observed)

# Display results
print(f"Chi-square Statistic: {chi2:.4f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of Freedom: {dof}")
print("\nExpected Frequencies:")
print(pd.DataFrame(expected, columns=["Product A", "Product B"], index=["Male", "Female"]))

# Interpretation
alpha = 0.05
if p < alpha:
    print("\nReject the null hypothesis: There is a significant relationship between gender and product preference.")
else:
    print("\nFail to reject the null hypothesis: No significant relationship between gender and product preference.")
# Out:
# Chi-square Statistic: 9.9556
# P-value: 0.0016
# Degrees of Freedom: 1
#
# Expected Frequencies:
#         Product A  Product B
# Male         22.5       17.5
# Female       22.5       17.5
#
# Reject the null hypothesis: There is a significant relationship between gender and product preference.

# %%
#Answer 13

import numpy as np
import pandas as pd
import scipy.stats as stats

def calculate_expected_frequencies(observed):
    """
    Calculate the expected frequencies for a Chi-square test.

    Parameters:
    - observed: 2D NumPy array or list of lists (contingency table)

    Returns:
    - Expected frequency table as a Pandas DataFrame
    """
    # Perform Chi-square test (scipy automatically calculates expected values)
    chi2, p, dof, expected = stats.chi2_contingency(observed)

    # Convert expected values into a DataFrame
    expected_df = pd.DataFrame(expected,
                               columns=["Category 1", "Category 2"],
                               index=["Group 1", "Group 2"])

    return expected_df

# Example observed data (contingency table)
observed_data = np.array([[30, 10],  # Group 1: 30 in Category 1, 10 in Category 2
                          [15, 25]]) # Group 2: 15 in Category 1, 25 in Category 2

# Compute expected frequencies
expected_frequencies = calculate_expected_frequencies(observed_data)

# Display results
print("Expected Frequencies:\n", expected_frequencies)
# Out:
# Expected Frequencies:
#           Category 1  Category 2
# Group 1        22.5        17.5
# Group 2        22.5        17.5

# %%
#Answer 14

import numpy as np
import scipy.stats as stats

# Observed frequencies from the dice rolls
observed_frequencies = np.array([15, 25, 18, 20, 22, 20])

# Expected frequencies (equal for a fair die)
expected_frequencies = np.array([20, 20, 20, 20, 20, 20])

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = stats.chisquare(f_obs=observed_frequencies, f_exp=expected_frequencies)

# Display results
print(f"Chi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("\nReject the null hypothesis: The die is not fair.")
else:
    print("\nFail to reject the null hypothesis: No significant evidence that the die is unfair.")
# Out:
# Chi-square Statistic: 2.9000
# P-value: 0.7154
#
# Fail to reject the null hypothesis: No significant evidence that the die is unfair.

# %%
#Answer 15

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def plot_chi_square_distribution():
    """
    Simulate and visualize the Chi-square distribution for different degrees of freedom.
    """
    df_values = [1, 2, 5, 10, 20]  # Different degrees of freedom
    x = np.linspace(0, 30, 1000)  # Range of Chi-square values

    plt.figure(figsize=(8, 5))

    for df in df_values:
        y = stats.chi2.pdf(x, df)  # Chi-square probability density function (PDF)
        plt.plot(x, y, label=f'df = {df}')

    # Plot customization
    plt.title("Chi-Square Distribution for Different Degrees of Freedom")
    plt.xlabel("Chi-square Value")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

# Run the function to visualize
plot_chi_square_distribution()

# %%
#Answer 16

import numpy as np
import scipy.stats as stats

def perform_f_test(sample1, sample2, alpha=0.05):
    """
    Perform an F-test to compare the variances of two independent samples.

    Parameters:
    - sample1: First dataset (numpy array or list)
    - sample2: Second dataset (numpy array or list)
    - alpha: Significance level (default: 0.05)

    Returns:
    - F-statistic and P-value
    """
    var1 = np.var(sample1, ddof=1)  # Sample variance (unbiased)
    var2 = np.var(sample2, ddof=1)

    # Ensure F-statistic is always >1 by setting larger variance in numerator
    if var1 > var2:
        F_stat = var1 / var2
        dfn, dfd = len(sample1) - 1, len(sample2) - 1  # Degrees of freedom
    else:
        F_stat = var2 / var1
        dfn, dfd = len(sample2) - 1, len(sample1) - 1

    # Compute p-value (two-tailed test)
    p_value = 2 * (1 - stats.f.cdf(F_stat, dfn, dfd))

    # Display results
    print(f"F-statistic: {F_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Interpretation
    if p_value < alpha:
        print("\nReject the null hypothesis: Variances are significantly different.")
    else:
        print("\nFail to reject the null hypothesis: No significant difference in variances.")

# Simulate two random samples
np.random.seed(42)  # For reproducibility
sample1 = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std Dev=10, Size=30
sample2 = np.random.normal(loc=50, scale=15, size=30)  # Mean=50, Std Dev=15, Size=30

# Perform F-test
perform_f_test(sample1, sample2)
# Out:
# F-statistic: 2.4082
# P-value: 0.0209
#
# Reject the null hypothesis: Variances are significantly different.

# %%
#Answer 17

import numpy as np
import scipy.stats as stats

# Simulate random data for three groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std Dev=10, Size=30
group2 = np.random.normal(loc=55, scale=10, size=30)  # Mean=55, Std Dev=10, Size=30
group3 = np.random.normal(loc=60, scale=10, size=30)  # Mean=60, Std Dev=10, Size=30

# Perform one-way ANOVA
F_stat, p_value = stats.f_oneway(group1, group2, group3)

# Display results
print(f"F-statistic: {F_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis: At least one group mean is significantly different.")
else:
    print("\nFail to reject the null hypothesis: No significant difference between group means.")
# Out:
# F-statistic: 12.2095
# P-value: 0.0000
#
# Reject the null hypothesis: At least one group mean is significantly different.

# %%
#Answer 18
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Simulate random data for three groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std Dev=10, Size=30
group2 = np.random.normal(loc=55, scale=10, size=30)  # Mean=55, Std Dev=10, Size=30
group3 = np.random.normal(loc=60, scale=10, size=30)  # Mean=60, Std Dev=10, Size=30

# Perform one-way ANOVA
F_stat, p_value = stats.f_oneway(group1, group2, group3)

# Display results
print(f"F-statistic: {F_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis: At least one group mean is significantly different.")
else:
    print("\nFail to reject the null hypothesis: No significant difference between group means.")

# ---- Visualization ----

# Convert data to a pandas DataFrame for plotting
df = pd.DataFrame({
    "Value": np.concatenate([group1, group2, group3]),
    "Group": ["Group 1"] * 30 + ["Group 2"] * 30 + ["Group 3"] * 30
})

# Create a boxplot to visualize distributions
plt.figure(figsize=(8, 5))
sns.boxplot(x="Group", y="Value", data=df, palette="Set2")

# Plot customization
plt.title("One-Way ANOVA: Group Comparisons")
plt.xlabel("Groups")
plt.ylabel("Values")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()
# Out:
# F-statistic: 12.2095
# P-value: 0.0000
#
# Reject the null hypothesis: At least one group mean is significantly different.
# <ipython-input-19-e84344a326a5>:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Group", y="Value", data=df, palette="Set2")

# %%
#Answer 19

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.formula.api import ols
from statsmodels.stats.api import anova_lm

def check_anova_assumptions(data, groups):
    """
    Check the assumptions for ANOVA: Normality, Independence, and Equal Variance (Homogeneity of variance).

    :param data: List or array-like of numerical values representing the response variable
    :param groups: List or array-like of group labels corresponding to the data
    :return: Prints results and plots for assumption checks
    """

    # 1. Check for Normality within each group (using Shapiro-Wilk Test)
    print("Checking Normality (Shapiro-Wilk Test):")
    unique_groups = np.unique(groups)
    for group in unique_groups:
        group_data = data[np.array(groups) == group]
        stat, p_value = stats.shapiro(group_data)
        print(f"Group {group}: Shapiro-Wilk p-value = {p_value}")
        if p_value < 0.05:
            print(f"Warning: Group {group} may not follow a normal distribution.")

    # 2. Check for Independence (visually with scatter plot or residuals plot)
    # Independence assumption usually comes from study design, so let's assume this
    # is validated externally. But we can check residuals plot if model is already fitted.
    print("\nChecking for Independence: This is typically validated by study design.")

    # 3. Check for Equal Variance (Homogeneity of variance) using Levene's Test
    print("\nChecking Equal Variance (Levene's Test):")
    stat, p_value = stats.levene(*[data[np.array(groups) == group] for group in unique_groups])
    print(f"Levene's Test p-value = {p_value}")
    if p_value < 0.05:
        print("Warning: Variance across groups may not be equal.")

    # Optional: Plot histograms to visually check normality assumption
    print("\nVisualizing distributions for normality check:")
    sns.boxplot(x=groups, y=data)
    plt.show()

# Example usage:
# Assuming you have data as a list/array and groups as a list/array of the same length
data = np.random.randn(100)  # Example data (normal distribution)
groups = ['Group1'] * 50 + ['Group2'] * 50  # Example group labels

check_anova_assumptions(data, groups)
# Out:
# Checking Normality (Shapiro-Wilk Test):
# Group Group1: Shapiro-Wilk p-value = 0.6895572336908335
# Group Group2: Shapiro-Wilk p-value = 0.6661797471740964
#
# Checking for Independence: This is typically validated by study design.
#
# Checking Equal Variance (Levene's Test):
# Levene's Test p-value = 0.5296401770906742
#
# Visualizing distributions for normality check:

# %%
#Answer 20

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# Step 1: Create Sample Data
np.random.seed(42)

# Factors
factor_A = np.repeat(['Low', 'High'], 30)  # Factor A (e.g., Treatment: Low vs. High)
factor_B = np.tile(['A', 'B', 'C'], 20)    # Factor B (e.g., Drug Type: A, B, C)

# Response variable (continuous)
data = 5 + 2 * (np.array(factor_A) == 'High') + 3 * (np.array(factor_B) == 'B') + \
       1.5 * (np.array(factor_B) == 'C') + np.random.randn(60)

# Create DataFrame
df = pd.DataFrame({'Factor_A': factor_A, 'Factor_B': factor_B, 'Response': data})

# Step 2: Perform Two-Way ANOVA
model = ols('Response ~ C(Factor_A) * C(Factor_B)', data=df).fit()
anova_results = anova_lm(model)

print("Two-Way ANOVA Results:\n", anova_results)

# Step 3: Visualize Interaction Effect
plt.figure(figsize=(8, 6))
sns.pointplot(data=df, x='Factor_A', y='Response', hue='Factor_B', capsize=0.1, markers=["o", "s", "D"])
plt.title("Interaction Plot: Factor A vs. Factor B")
plt.show()

# Step 4: Boxplot to Show Distributions
plt.figure(figsize=(8, 6))
sns.boxplot(x='Factor_A', y='Response', hue='Factor_B', data=df)
plt.title("Boxplot of Response by Factors")
plt.show()
# Out:
# Two-Way ANOVA Results:
#                             df     sum_sq    mean_sq          F        PR(>F)
# C(Factor_A)               1.0  64.086369  64.086369  76.006131  6.959001e-12
# C(Factor_B)               2.0  72.053122  36.026561  42.727332  7.497896e-12
# C(Factor_A):C(Factor_B)   2.0   1.774253   0.887127   1.052128  3.562416e-01
# Residual                 54.0  45.531379   0.843174        NaN           NaN

# %%
#Answer 21

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def plot_f_distribution(dfn, dfd):
    """
    Plots the F-distribution for given degrees of freedom.

    Parameters:
    dfn (int): Degrees of freedom for the numerator.
    dfd (int): Degrees of freedom for the denominator.
    """
    x = np.linspace(0, 5, 1000)  # Range of F-values
    f_pdf = stats.f.pdf(x, dfn, dfd)  # Probability density function

    # Plot F-distribution
    plt.figure(figsize=(8, 5))
    plt.plot(x, f_pdf, label=f"F({dfn}, {dfd})", color='blue')

    # Highlight the critical region (right tail)
    alpha = 0.05  # Significance level
    f_critical = stats.f.ppf(1 - alpha, dfn, dfd)
    x_critical = np.linspace(f_critical, 5, 200)
    plt.fill_between(x_critical, stats.f.pdf(x_critical, dfn, dfd), alpha=0.3, color='red', label="Rejection Region (α=0.05)")

    # Labels and legend
    plt.axvline(f_critical, linestyle='dashed', color='red', label=f"Critical F-value = {f_critical:.2f}")
    plt.title(f"F-Distribution (dfn={dfn}, dfd={dfd})")
    plt.xlabel("F-value")
    plt.ylabel("Density")
    plt.legend()
    plt.grid()

    # Show the plot
    plt.show()

# Example: Plot an F-distribution with 5 and 10 degrees of freedom
plot_f_distribution(dfn=5, dfd=10)

# %%
#Answer 22

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Generate sample data
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=10, size=30)
group3 = np.random.normal(loc=60, scale=10, size=30)

# Perform One-Way ANOVA
f_stat, p_value = stats.f_oneway(group1, group2, group3)

# Print results
print(f"F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")

# Visualization with boxplots
data = [group1, group2, group3]
labels = ['Group 1', 'Group 2', 'Group 3']

plt.figure(figsize=(8, 5))
sns.boxplot(data=data)
plt.xticks(ticks=[0, 1, 2], labels=labels)
plt.title('Boxplot of Groups')
plt.ylabel('Values')
plt.grid(True)

plt.show()
# Out:
# F-statistic: 12.2095, P-value: 0.0000

# %%
#Answer 23

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Simulate random data from normal distributions
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Mean = 50, Std Dev = 10
group2 = np.random.normal(loc=55, scale=10, size=30)  # Mean = 55, Std Dev = 10

# Perform an independent t-test
t_stat, p_value = stats.ttest_ind(group1, group2)

# Print test results
print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")

# Visualization: Boxplot
plt.figure(figsize=(7, 5))
sns.boxplot(data=[group1, group2])
plt.xticks(ticks=[0, 1], labels=['Group 1', 'Group 2'])
plt.title('Comparison of Two Groups')
plt.ylabel('Values')
plt.grid(True)
plt.show()
# Out:
# T-statistic: -2.3981, P-value: 0.0197

# %%
#Answer 24

import numpy as np
import scipy.stats as stats

# Generate random sample data (normal distribution)
np.random.seed(42)
sample = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std=10, Size=30

# Hypothesized variance (σ0^2)
sigma0_squared = 100  # (10^2)

# Sample statistics
n = len(sample)
sample_variance = np.var(sample, ddof=1)  # Unbiased sample variance

# Chi-square test statistic
chi_square_stat = (n - 1) * sample_variance / sigma0_squared

# Compute p-value (two-tailed test)
p_value = 2 * min(
    stats.chi2.cdf(chi_square_stat, df=n - 1),
    1 - stats.chi2.cdf(chi_square_stat, df=n - 1)
)

# Print results
print(f"Chi-square Statistic: {chi_square_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject H₀: The population variance is significantly different from the hypothesized value.")
else:
    print("Fail to reject H₀: No significant difference in variance.")
# Out:
# Chi-square Statistic: 23.4903
# P-value: 0.4927
# Fail to reject H₀: No significant difference in variance.

# %%
#Answer 25

import numpy as np
import scipy.stats as stats

def z_test_proportions(x1, n1, x2, n2):
    # Sample proportions
    p1 = x1 / n1
    p2 = x2 / n2

    # Pooled proportion
    p_pooled = (x1 + x2) / (n1 + n2)

    # Standard error
    se = np.sqrt(p_pooled * (1 - p_pooled) * (1/n1 + 1/n2))

    # Z-score
    z_score = (p1 - p2) / se

    # P-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    return z_score, p_value

# Example Data: Group 1 (successes: 40, total: 200), Group 2 (successes: 55, total: 220)
x1, n1 = 40, 200  # Group 1
x2, n2 = 55, 220  # Group 2

# Perform Z-test
z_stat, p_val = z_test_proportions(x1, n1, x2, n2)

# Print Results
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_val:.4f}")

# Interpretation
alpha = 0.05
if p_val < alpha:
    print("Reject H₀: The proportions are significantly different.")
else:
    print("Fail to reject H₀: No significant difference in proportions.")
# Out:
# Z-statistic: -1.2233
# P-value: 0.2212
# Fail to reject H₀: No significant difference in proportions.

# %%
#Answer 26

import numpy as np
import scipy.stats as stats

def z_test_proportions(x1, n1, x2, n2):
    """
    Performs a Z-test for proportions to compare two independent groups.

    Parameters:
        x1 (int): Number of successes in group 1
        n1 (int): Total observations in group 1
        x2 (int): Number of successes in group 2
        n2 (int): Total observations in group 2

    Returns:
        tuple: (Z-statistic, P-value)
    """
    # Sample proportions
    p1 = x1 / n1
    p2 = x2 / n2

    # Pooled proportion
    p_pooled = (x1 + x2) / (n1 + n2)

    # Standard error
    se = np.sqrt(p_pooled * (1 - p_pooled) * (1/n1 + 1/n2))

    # Compute Z-score
    z_score = (p1 - p2) / se

    # Compute p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    return z_score, p_value

# Example: Compare two groups
x1, n1 = 50, 200  # Group 1: 50 successes out of 200
x2, n2 = 60, 220  # Group 2: 60 successes out of 220

# Perform Z-test
z_stat, p_val = z_test_proportions(x1, n1, x2, n2)

# Print results
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_val:.4f}")

# Interpretation
alpha = 0.05
if p_val < alpha:
    print("Reject H₀: The proportions are significantly different.")
else:
    print("Fail to reject H₀: No significant difference in proportions.")
# Out:
# Z-statistic: -0.5291
# P-value: 0.5968
# Fail to reject H₀: No significant difference in proportions.

# %%
#Answer 26

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Generate two random datasets
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std=10
group2 = np.random.normal(loc=55, scale=15, size=30)  # Mean=55, Std=15

# Compute sample variances
var1 = np.var(group1, ddof=1)
var2 = np.var(group2, ddof=1)

# Compute F-statistic (ensure F >= 1)
if var1 > var2:
    F_stat = var1 / var2
    dfn, dfd = len(group1) - 1, len(group2) - 1
else:
    F_stat = var2 / var1
    dfn, dfd = len(group2) - 1, len(group1) - 1

# Compute p-value (two-tailed test)
p_value = 2 * (1 - stats.f.cdf(F_stat, dfn, dfd))

# Print results
print(f"F-statistic: {F_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject H₀: The variances are significantly different.")
else:
    print("Fail to reject H₀: No significant difference in variances.")

# Visualization: Boxplot
plt.figure(figsize=(7, 5))
sns.boxplot(data=[group1, group2])
plt.xticks(ticks=[0, 1], labels=['Group 1', 'Group 2'])
plt.title('Variance Comparison of Two Groups')
plt.ylabel('Values')
plt.grid(True)
plt.show()
# Out:
# F-statistic: 2.4082
# P-value: 0.0209
# Reject H₀: The variances are significantly different.

# %%
#Answer 27

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Simulated observed data (e.g., frequency of categories)
observed = np.array([50, 30, 20])  # Example: 3 categories

# Expected distribution (assuming uniform expected frequencies)
total_observed = np.sum(observed)
expected = np.array([total_observed / len(observed)] * len(observed))

# Perform Chi-square goodness-of-fit test
chi_square_stat, p_value = stats.chisquare(f_obs=observed, f_exp=expected)

# Print results
print(f"Chi-square Statistic: {chi_square_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject H₀: The observed distribution does not match the expected distribution.")
else:
    print("Fail to reject H₀: No significant difference between observed and expected distributions.")

# Visualization: Bar Plot
categories = ['Category 1', 'Category 2', 'Category 3']
x = np.arange(len(categories))

plt.bar(x - 0.2, observed, width=0.4, label='Observed', color='blue')
plt.bar(x + 0.2, expected, width=0.4, label='Expected', color='orange')
plt.xticks(x, categories)
plt.xlabel("Categories")
plt.ylabel("Frequency")
plt.title("Chi-Square Goodness-of-Fit Test")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()
# Out:
# Chi-square Statistic: 14.0000
# P-value: 0.0009
# Reject H₀: The observed distribution does not match the expected distribution.
